# %% [markdown]
# # The eigenvalue problem

# %%
import numpy as np
import matplotlib.pyplot as plt

from eigenSolver import EigenSolver

# %% [markdown]
# ## Random 6x6 example, smallest and larges eigenvalues
#
# 7 min first
# 14 min second

# %%
np.random.seed(21)
# Setting up data
N = 6
Q = np.random.rand(N, N)
A = (Q.T + Q)/2
x0 = np.random.rand(N, 1)

T = 10
dt = T / 10

print(f"A = \n{A}")
print(f"\nx0 = {x0[:, 0].T}")

eigenvalues, v = np.linalg.eig(A)
print("\n All eigenvalues and eigenvectors:")
print(f" {eigenvalues}")
print(v)
# Out:
# A =
# [[0.04872488 0.29569078 0.42710343 0.3904594  0.55954337 0.18899292]
#  [0.29569078 0.66391029 0.24311953 0.48392065 0.41516351 0.66377241]
#  [0.42710343 0.24311953 0.49592955 0.63620899 0.63780619 0.75742674]
#  [0.3904594  0.48392065 0.63620899 0.71336043 0.21925277 0.53575187]
#  [0.55954337 0.41516351 0.63780619 0.21925277 0.29869229 0.54190569]
#  [0.18899292 0.66377241 0.75742674 0.53575187 0.54190569 0.72668445]]
#
# x0 = [0.84929271 0.2675218  0.61482471 0.65275607 0.38681643 0.41035418]
#
#  All eigenvalues and eigenvectors:
#  [ 2.90759896 -0.50203156 -0.40458305  0.18207582  0.42070312  0.3435386 ]
# [[-0.27198426 -0.64557108 -0.34102226  0.56030744 -0.26949705  0.07995791]
#  [-0.39251987 -0.04959397  0.36732535  0.31888964  0.7616472   0.16353475]
#  [-0.45418352 -0.17796292  0.69252519 -0.23083144 -0.4781968  -0.02236217]
#  [-0.42515047  0.27933971 -0.18280658  0.12857474  0.0119146  -0.83133912]
#  [-0.37087114  0.66278204 -0.16458715  0.27522975 -0.28839532  0.48699317]
#  [-0.49736477 -0.17831686 -0.45681243 -0.662419    0.18782673  0.19513064]]

# %%
model6 = EigenSolver(A, x0, dt, T)
model6.train(2000)
# Out:
# Finished training with a loss of 1.5386364350791526e-05 after 28m 29.139220476150513s.

# %%
model6.evaluate()
# Out:
# Eigenvalue = 2.90792 +- 0.00220
# Real eigen = 2.907599, diff = 0.00032
# Eigenvector =   [0.27188827 0.39211333 0.45444187 0.4256815  0.3704482  0.49736293]
# Real eigenvec = [0.27198426 0.39251987 0.45418352 0.42515047 0.37087114 0.49736477]

# %%
model6small = EigenSolver(-A, x0, dt, T)
model6small.train(2000)
# Out:
# Finished training with a loss of 0.0024015638405045668 after 27m 55.821614265441895s.

# %%
model6small.evaluate(-1)
# Out:
# Eigenvalue = 1.09177 +- 1.44096
# Real eigen = 0.182076, diff = 0.90969
# Eigenvector =   [ 0.86843646 -0.04472619 -0.01114049  0.12219788 -0.29738866 -0.37459475]
# Real eigenvec = [ 0.56030744  0.31888964 -0.23083144  0.12857474  0.27522975 -0.662419  ]

# %% [markdown]
# ## Random 3x3 example, smallest and larges eigenvalues

# %% [markdown]
# 7 min first
# 14 min second

# %%
np.random.seed(0)
# Setting up data
N = 3
Q = np.random.rand(N, N)
A = (Q.T + Q)/2
x0 = np.random.rand(N, 1)

T = 10
dt = T / 10

print(f"A = \n{A}")
print(f"\nx0 = {x0[:, 0].T}")

eigenvalues, v = np.linalg.eig(A)
print("\n All eigenvalues and eigenvectors:")
print(f" {eigenvalues}")
print(v)
# Out:
# A =
# [[0.5488135  0.63003627 0.52017529]
#  [0.63003627 0.4236548  0.76883356]
#  [0.52017529 0.76883356 0.96366276]]
#
# x0 = [0.38344152 0.79172504 0.52889492]
#
#  All eigenvalues and eigenvectors:
#  [ 1.95717583  0.20837604 -0.22942081]
# [[-0.49381311 -0.74812303  0.44323869]
#  [-0.54328049 -0.13256429 -0.82901931]
#  [-0.67896606  0.65018354  0.34097867]]

# %%
T = 10
dt = T / 10

# %%
model3 = EigenSolver(A, x0, dt, T)
model3.train(2000)
# Out:
# Finished training with a loss of 3.5310509867357475e-06 after 27m 45.1085422039032s.

# %%
model3.evaluate()
# Out:
# Eigenvalue = 1.95691 +- 0.00152
# Real eigen = 1.957176, diff = -0.00026
# Eigenvector =   [0.49445192 0.54305671 0.67868012]
# Real eigenvec = [0.49381311 0.54328049 0.67896606]

# %%
model3small = EigenSolver(-A, x0, dt, T)
model3small.train(2000)
# Out:
# Finished training with a loss of 6.657532452043492e-05 after 27m 47.91684079170227s.

# %%
model3small.evaluate(-1)
# Out:
# Eigenvalue = -0.23605 +- 0.00912
# Real eigen = 0.208376, diff = -0.44443
# Eigenvector =   [-0.43598033  0.83205107 -0.34294631]
# Real eigenvec = [-0.74812303 -0.13256429  0.65018354]

# %% [markdown]
# ## Random 9x9 example, smallest and larges eigenvalues

# %% [markdown]
# 7 min first
# 14 min second

# %%
np.random.seed(0)
# Setting up data
N = 9
Q = np.random.rand(N, N)
A = (Q.T + Q)/2
x0 = np.random.rand(N, 1)

T = 10
dt = T / 10

print(f"A = \n{A}")
print(f"\nx0 = {x0[:, 0].T}")

eigenvalues, v = np.linalg.eig(A)
print("\n All eigenvalues and eigenvectors:")
print(f" {eigenvalues}")
print(v)
# Out:
# A =
# [[0.5488135  0.54931544 0.69046006 0.74477605 0.51787526 0.65826599
#   0.32323198 0.51497798 0.97021192]
#  [0.54931544 0.79172504 0.69945353 0.54494644 0.77126532 0.14070931
#   0.12421941 0.10840038 0.71873268]
#  [0.69046006 0.69945353 0.97861834 0.60691025 0.70261372 0.45472774
#   0.38569138 0.5043231  0.44130843]
#  [0.74477605 0.54494644 0.60691025 0.26455561 0.72802699 0.38578934
#   0.41086278 0.41989152 0.32841164]
#  [0.51787526 0.77126532 0.70261372 0.72802699 0.3595079  0.40037136
#   0.58197098 0.07866337 0.47478684]
#  [0.65826599 0.14070931 0.45472774 0.38578934 0.40037136 0.57019677
#   0.34151355 0.91315937 0.11112069]
#  [0.32323198 0.12421941 0.38569138 0.41086278 0.58197098 0.34151355
#   0.15896958 0.10323677 0.47623489]
#  [0.51497798 0.10840038 0.5043231  0.41989152 0.07866337 0.91315937
#   0.10323677 0.97645947 0.29368946]
#  [0.97021192 0.71873268 0.44130843 0.32841164 0.47478684 0.11112069
#   0.47623489 0.29368946 0.31798318]]
#
# x0 = [0.41426299 0.0641475  0.69247212 0.56660145 0.26538949 0.52324805
#  0.09394051 0.5759465  0.9292962 ]
#
#  All eigenvalues and eigenvectors:
#  [ 4.51113021  1.38843784 -0.8617499  -0.57657167  0.40247856  0.35462084
#   0.07703024 -0.14217761 -0.18636911]
# [[-0.40804271 -0.03119564 -0.54033434  0.04525102 -0.44652569  0.09030242
#   -0.24537342 -0.51735222  0.05583875]
#  [-0.34600216  0.42008603 -0.17255848 -0.34019388 -0.08906632 -0.50117742
#    0.48165026  0.17920549  0.18731986]
#  [-0.41512382  0.05806175  0.07883278 -0.02944291  0.58983459 -0.3234768
#   -0.59478718 -0.03377913  0.09881621]
#  [-0.33415431  0.04047049  0.3516417  -0.3036201   0.11221753  0.16945556
#    0.23032525 -0.38016314 -0.65725512]
#  [-0.34398251  0.25659454 -0.09896525  0.74247744  0.26548091  0.26720643
#    0.32392652  0.08511749 -0.02675138]
#  [-0.28968798 -0.48614811  0.29797456 -0.12718818  0.10327704  0.21290692
#    0.30190402 -0.19224444  0.6250406 ]
#  [-0.21844015  0.07087724 -0.28012632 -0.42387524  0.09497914  0.62973672
#   -0.1351969   0.51499849 -0.00532196]
#  [-0.28402408 -0.68680194 -0.16229958  0.13686935 -0.10643246 -0.30506635
#    0.08145149  0.40882217 -0.35269788]
#  [-0.31490934  0.19658154  0.58736786  0.1526938  -0.57505583  0.03085121
#   -0.28283638  0.27929395  0.06502975]]

# %%
T = 10
dt = T / 10

# %%
model9 = EigenSolver(A, x0, dt, T)
model9.train(2000)
# Out:
# Finished training with a loss of 1.714569762425426e-05 after 27m 48.06808662414551s.

# %%
model9.evaluate()
# Out:
# Eigenvalue = 4.51152 +- 0.00302
# Real eigen = 4.511130, diff = 0.00039
# Eigenvector =   [0.40840313 0.34589665 0.41533933 0.33400039 0.34375658 0.28991141
#  0.21841383 0.28401067 0.31450833]
# Real eigenvec = [0.40804271 0.34600216 0.41512382 0.33415431 0.34398251 0.28968798
#  0.21844015 0.28402408 0.31490934]

# %%
model9small = EigenSolver(-A, x0, dt, T)
model9small.train(2000)
# Out:
# Finished training with a loss of 1.8593170158526897e-05 after 27m 48.80354070663452s.

# %%
model9small.evaluate(-1)
# Out:
# Eigenvalue = -0.87007 +- 0.02441
# Real eigen = 0.077030, diff = -0.94710
# Eigenvector =   [-0.53755344 -0.18016627  0.07758893  0.34321805 -0.0819526   0.29529686
#  -0.28942244 -0.15849058  0.59325936]
# Real eigenvec = [-0.24537342  0.48165026 -0.59478718  0.23032525  0.32392652  0.30190402
#  -0.1351969   0.08145149 -0.28283638]

# %% [markdown]
# ## More 6x6 example, different number of time steps
#
# 7 min first
# 14 min second

# %%
np.random.seed(21)
# Setting up data
N = 6
Q = np.random.rand(N, N)
A = (Q.T + Q)/2
x0 = np.random.rand(N, 1)

print(f"A = \n{A}")
print(f"\nx0 = {x0[:, 0].T}")

eigenvalues, v = np.linalg.eig(A)
print("\n All eigenvalues and eigenvectors:")
print(f" {eigenvalues}")
print(v)
# Out:
# A =
# [[0.04872488 0.29569078 0.42710343 0.3904594  0.55954337 0.18899292]
#  [0.29569078 0.66391029 0.24311953 0.48392065 0.41516351 0.66377241]
#  [0.42710343 0.24311953 0.49592955 0.63620899 0.63780619 0.75742674]
#  [0.3904594  0.48392065 0.63620899 0.71336043 0.21925277 0.53575187]
#  [0.55954337 0.41516351 0.63780619 0.21925277 0.29869229 0.54190569]
#  [0.18899292 0.66377241 0.75742674 0.53575187 0.54190569 0.72668445]]
#
# x0 = [0.84929271 0.2675218  0.61482471 0.65275607 0.38681643 0.41035418]
#
#  All eigenvalues and eigenvectors:
#  [ 2.90759896 -0.50203156 -0.40458305  0.18207582  0.42070312  0.3435386 ]
# [[-0.27198426 -0.64557108 -0.34102226  0.56030744 -0.26949705  0.07995791]
#  [-0.39251987 -0.04959397  0.36732535  0.31888964  0.7616472   0.16353475]
#  [-0.45418352 -0.17796292  0.69252519 -0.23083144 -0.4781968  -0.02236217]
#  [-0.42515047  0.27933971 -0.18280658  0.12857474  0.0119146  -0.83133912]
#  [-0.37087114  0.66278204 -0.16458715  0.27522975 -0.28839532  0.48699317]
#  [-0.49736477 -0.17831686 -0.45681243 -0.662419    0.18782673  0.19513064]]

# %%
T = 10
dt = T / 5
model6_5 = EigenSolver(A, x0, dt, T)
model6_5.train(2000)
# Out:
# Finished training with a loss of 6.015526275206885e-07 after 27m 48.97489094734192s.

# %%
model6_5.evaluate()
# Out:
# Eigenvalue = 2.90757 +- 0.00110
# Real eigen = 2.907599, diff = -0.00003
# Eigenvector =   [0.27203627 0.39267996 0.45397843 0.42496671 0.37079206 0.49761316]
# Real eigenvec = [0.27198426 0.39251987 0.45418352 0.42515047 0.37087114 0.49736477]

# %%
T = 10
dt = T / 50
model6_50 = EigenSolver(A, x0, dt, T)
model6_50.train(2000)
# Out:
# Finished training with a loss of 3.184567889808773e-05 after 27m 54.706934213638306s.

# %%
model6_50.evaluate()
# Out:
# Eigenvalue = 2.90899 +- 0.00579
# Real eigen = 2.907599, diff = 0.00140
# Eigenvector =   [0.27073132 0.39316002 0.45407597 0.42482735 0.37082333 0.49795236]
# Real eigenvec = [0.27198426 0.39251987 0.45418352 0.42515047 0.37087114 0.49736477]

# %%
T = 10
dt = T / 100
model6_100 = EigenSolver(A, x0, dt, T)
model6_100.train(2000)
# Out:
# Finished training with a loss of 6.645270748261841e-05 after 28m 2.622462511062622s.

# %%
model6_100.evaluate()
# Out:
# Eigenvalue = 2.90999 +- 0.02202
# Real eigen = 2.907599, diff = 0.00239
# Eigenvector =   [0.26889243 0.39169054 0.45247195 0.42707917 0.37427959 0.49705401]
# Real eigenvec = [0.27198426 0.39251987 0.45418352 0.42515047 0.37087114 0.49736477]

# %% [markdown]
# ## Even more 6x6, to see how often it fails

# %%
for seed in [2020, 2021, 2022, 2023]:
    np.random.seed(seed)
    # Setting up data
    N = 6
    Q = np.random.rand(N, N)
    A = (Q.T + Q)/2
    x0 = np.random.rand(N, 1)

    T = 10
    dt = T / 10

    print(f"A = \n{A}")
    print(f"\nx0 = {x0[:, 0].T}")

    eigenvalues, v = np.linalg.eig(A)
    print("\n All eigenvalues and eigenvectors:")
    print(f" {eigenvalues}")
    print(v)

    model = EigenSolver(A, x0, dt, T)
    model.train(2000)

    model.evaluate()
# Out:
# A =
# [[0.98627683 0.57493454 0.62303522 0.19800725 0.42014289 0.19332835]
#  [0.57493454 0.34331559 0.60891101 0.23821808 0.40427573 0.82666931]
#  [0.62303522 0.60891101 0.34109302 0.81000846 0.12564607 0.46741037]
#  [0.19800725 0.23821808 0.81000846 0.13735679 0.51276623 0.67767921]
#  [0.42014289 0.40427573 0.12564607 0.51276623 0.15585136 0.66718278]
#  [0.19332835 0.82666931 0.46741037 0.67767921 0.66718278 0.64606105]]
#
# x0 = [0.5834617  0.66835003 0.17779262 0.84924802 0.44237258 0.83146771]
#
#  All eigenvalues and eigenvectors:
#  [ 2.92910435  0.80255834 -0.85170374 -0.51710308  0.00495393  0.24214483]
# [[-0.41614741 -0.81117174  0.11048076  0.30064015  0.18328663 -0.18065782]
#  [-0.42866978  0.00191949  0.33434917 -0.47801702 -0.63887461 -0.26036154]
#  [-0.41729421 -0.10457379 -0.56721729 -0.14224568 -0.18111163  0.66344491]
#  [-0.36359475  0.25527797  0.64716023 -0.01385447  0.40162819  0.47150663]
#  [-0.32699649  0.16150787 -0.32696735 -0.49930563  0.58795056 -0.40631131]
#  [-0.47937589  0.48970339 -0.16895314  0.64139172 -0.13584091 -0.26834323]]
# Finished training with a loss of 1.138124705705764e-05 after 27m 50.85649633407593s.
# Eigenvalue = 2.92850 +- 0.00416
# Real eigen = 2.929104, diff = -0.00061
# Eigenvector =   [0.4151614  0.42873118 0.41720374 0.36380233 0.32792022 0.47946619]
# Real eigenvec = [0.41614741 0.42866978 0.41729421 0.36359475 0.32699649 0.47937589]
# A =
# [[0.60597828 0.45618123 0.55067157 0.44348869 0.79047365 0.40014566]
#  [0.45618123 0.75292543 0.63935898 0.57773549 0.28660393 0.35102805]
#  [0.55067157 0.63935898 0.08662996 0.5067088  0.56716955 0.8959287 ]
#  [0.44348869 0.57773549 0.5067088  0.20185025 0.69620188 0.19978268]
#  [0.79047365 0.28660393 0.56716955 0.69620188 0.73222503 0.34327261]
#  [0.40014566 0.35102805 0.8959287  0.19978268 0.34327261 0.61770101]]
#
# x0 = [0.30106862 0.87174059 0.58965408 0.98177009 0.44223223 0.12631769]
#
#  All eigenvalues and eigenvectors:
#  [ 3.09077725 -0.71694409 -0.41386074 -0.03591279  0.61909512  0.4541552 ]
# [[-0.43525105 -0.05319095 -0.22066916 -0.80560179  0.31111381  0.11509266]
#  [-0.40001405 -0.1514358   0.35560662 -0.11115185 -0.34435107 -0.74810928]
#  [-0.42189699  0.84611776 -0.0751359   0.10651153 -0.270084    0.12709124]
#  [-0.35624675 -0.19154497 -0.72377785  0.4427421   0.20335964 -0.27416909]
#  [-0.4552404  -0.06988485  0.54335331  0.35178105  0.57365462  0.19952428]
#  [-0.37201161 -0.46556341 -0.01079112  0.08680926 -0.58416642  0.5440178 ]]
# Finished training with a loss of 0.000597483549722784 after 27m 53.23490309715271s.
# Eigenvalue = 3.08899 +- 0.02360
# Real eigen = 3.090777, diff = -0.00178
# Eigenvector =   [0.43290301 0.40511088 0.42014942 0.36064815 0.45376611 0.36875989]
# Real eigenvec = [0.43525105 0.40001405 0.42189699 0.35624675 0.4552404  0.37201161]
# A =
# [[0.00935861 0.69835752 0.47348164 0.51375183 0.35203566 0.52583024]
#  [0.69835752 0.64745207 0.92700373 0.408784   0.67754543 0.58849868]
#  [0.47348164 0.92700373 0.36804444 0.61952192 0.60197266 0.79766898]
#  [0.51375183 0.408784   0.61952192 0.29249947 0.3437591  0.39514676]
#  [0.35203566 0.67754543 0.60197266 0.3437591  0.21219185 0.6347252 ]
#  [0.52583024 0.58849868 0.79766898 0.39514676 0.6347252  0.3578826 ]]
#
# x0 = [0.74796395 0.91450931 0.37266242 0.96488347 0.08138577 0.04245099]
#
#  All eigenvalues and eigenvectors:
#  [ 3.25874054 -0.70991436  0.06369439 -0.0674941  -0.34715389 -0.31044354]
# [[-0.33483824 -0.50190326  0.2044556   0.25408941  0.54884446  0.47789404]
#  [-0.49826128  0.44423694 -0.35901247  0.6496374  -0.05846808 -0.00721281]
#  [-0.47554133 -0.52880514  0.01118852 -0.06040401 -0.69775771 -0.05988257]
#  [-0.32404645  0.30976588  0.84398723  0.00498911  0.02437107 -0.29343776]
#  [-0.36690121 -0.16870723 -0.31886238 -0.30852124  0.4559261  -0.65741477]
#  [-0.4169615   0.38300751 -0.12326849 -0.6438563   0.00478148  0.49967933]]
# Finished training with a loss of 0.001060700587123614 after 28m 0.9997563362121582s.
# Eigenvalue = 3.25410 +- 0.06087
# Real eigen = 3.258741, diff = -0.00464
# Eigenvector =   [0.34465482 0.49523724 0.47818779 0.31994359 0.37076441 0.40921806]
# Real eigenvec = [0.33483824 0.49826128 0.47554133 0.32404645 0.36690121 0.4169615 ]
# A =
# [[0.3219883  0.45625606 0.4912604  0.25879375 0.16269768 0.61402765]
#  [0.45625606 0.72727471 0.33777982 0.29029172 0.28016255 0.63607325]
#  [0.4912604  0.33777982 0.36087518 0.36346933 0.39644296 0.38851192]
#  [0.25879375 0.29029172 0.36346933 0.20346149 0.25823415 0.58409246]
#  [0.16269768 0.28016255 0.39644296 0.25823415 0.37852542 0.87043513]
#  [0.61402765 0.63607325 0.38851192 0.58409246 0.87043513 0.98055723]]
#
# x0 = [0.88478525 0.10980113 0.81971076 0.30761289 0.26149467 0.40572354]
#
#  All eigenvalues and eigenvectors:
#  [ 2.79860702 -0.47703062  0.44551279  0.2519651  -0.03907098 -0.00730098]
# [[-0.3479575  -0.43033986 -0.3645577   0.31709625 -0.55236507  0.39392088]
#  [-0.41023982 -0.03311206 -0.63649978 -0.55697975  0.17873249 -0.28862289]
#  [-0.32990578  0.40117729 -0.18059757  0.69110192  0.08185235 -0.46182444]
#  [-0.30107849 -0.28215509  0.05740513  0.21391414  0.78441538  0.40666712]
#  [-0.37580756 -0.5438669   0.53133872 -0.05981958 -0.09393129 -0.51793355]
#  [-0.60820348  0.5266548   0.37912273 -0.24952761 -0.17921254  0.3385381 ]]
# Finished training with a loss of 0.0008108103768193963 after 27m 55.437517166137695s.
# Eigenvalue = 2.79730 +- 0.00965
# Real eigen = 2.798607, diff = -0.00131
# Eigenvector =   [0.35014879 0.40835491 0.32950525 0.30118891 0.37665275 0.60785387]
# Real eigenvec = [0.3479575  0.41023982 0.32990578 0.30107849 0.37580756 0.60820348]
