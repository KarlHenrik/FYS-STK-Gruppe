# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# symmetric matrix
Q = np.random.rand(6,6)
A = (Q.T + Q)/2
print(A)
# Out:
# [[0.17744973 0.62918259 0.84462831 0.45605248 0.22907387 0.29863176]
#  [0.62918259 0.86748363 0.26052991 0.7620727  0.77087483 0.68487057]
#  [0.84462831 0.26052991 0.97025951 0.12543803 0.55379958 0.46422154]
#  [0.45605248 0.7620727  0.12543803 0.20564217 0.47403276 0.73322172]
#  [0.22907387 0.77087483 0.55379958 0.47403276 0.74281017 0.75751593]
#  [0.29863176 0.68487057 0.46422154 0.73322172 0.75751593 0.44014683]]

# %%
# eigenvalues from max to min
eigenvalues, v = np.linalg.eig(A)
print(eigenvalues)
# Out:
# [ 3.31223639  0.95062664  0.29794255 -0.66411016 -0.44285173 -0.05005165]

# %%
def eigenvecsolver(xin, A, nits, dt): # xin is inputvector
    x = np.zeros((len(xin),nits))
    x[:,0] = xin
    for i in range(nits-1):
        x[:,i+1] = x[:,i] + (xin.T @ xin * A + (1 - xin.T @ A * xin) * np.eye(len(A))) @ xin * dt
    return x

# %%
xtry = np.random.rand(6)
nits = 100
dt = 0.001
x = eigenvecsolver(xtry,A,nits,dt)
t = np.linspace(0,nits,nits)

# %%
for i in range(len(x)):
    plt.plot(t,x[i,:])
