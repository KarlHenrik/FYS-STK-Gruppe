# %%
import numpy as np
import matplotlib.pyplot as plt

from diffusionExplicit import expScheme
from diffusionTf import DiffusionTf
from diffusionUtils import *

# %%
dx = 0.1
L = 1

dt = dx**2 * 0.5
T = 0.5

# %%
model = DiffusionTf(dx, dt, L, T)

# %%
x, t, U = model.train(10000)

# %%
plot3D(x, t, U)
error(x, t, U)
# Out:
# Max abs error: 0.0009411139294093207
# Mean abs error: 0.00017971352818240045

# %%
x, t, U = expScheme(dx, dt, L, T)
plot3D(x, t, U)
error(x, t, U)
# Out:
# Max abs error: 0.002466329079496954
# Mean abs error: 0.0007375164625575349

# %%
x, t, U = analyticSolv(dx, dt, L, T)
plot3D(x, t, U)
error(x, t, U)
# Out:
# Max abs error: 0.0
# Mean abs error: 0.0
